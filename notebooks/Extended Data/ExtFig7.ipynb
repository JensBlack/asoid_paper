  [18.023273229599, 18.92208743095398, 20.29199528694153],
  [19.863092184066772, 20.11295485496521, 17.680619955062866],
  [18.329238653182983, 19.580183506011963, 17.684621572494507],
  [18.48924493789673, 20.073717832565308, 19.524699211120605],
  [19.758299350738525, 18.995790719985962, 18.140809059143066],
  [19.536099195480347, 17.895127058029175, 18.27395749092102],
  [20.397175312042236, 18.226068258285522, 18.673933029174805],
  [21.24220609664917, 19.788150548934937, 20.80432367324829],
  [19.74494218826294, 19.063326835632324, 18.523905754089355],
  [18.571425676345825, 19.617539405822754, 18.487982988357544],
  [18.69095516204834, 20.74053692817688, 19.50924777984619],
  [21.050554990768433, 18.625475645065308, 19.501492738723755],
  [19.49701976776123, 18.512033224105835, 18.679882764816284]]

benchmark_dict[1.0]["extraction"] = [72.41994833946228, 71.86077904701233, 71.53636145591736]\



for key in benchmark_dict.keys():
    benchmark_dict[key]["learning"] = np.array(benchmark_dict[key]["learning"])
    benchmark_dict[key]["extraction"] = np.array(benchmark_dict[key]["extraction"])

# %%
#calculate total time per seed
for key in benchmark_dict.keys():
    curr_time = np.vstack([benchmark_dict[key]["learning"] ,benchmark_dict[key]["extraction"]])
    benchmark_dict[key]["total"] = curr_time.sum(axis=0)

# %% [markdown]
# # Runtime of feature extraction

# %%
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

def func(x, a,c):
    return a*x+c

x = np.array([benchmark_dict[key]["n_samples"] for key in benchmark_dict.keys()])
y = [benchmark_dict[key]["extraction"].mean() for key in benchmark_dict.keys()]

popt, pcov = curve_fit(func, x, y)

y_pred = func(x, *popt)
r2 = r2_score(y, y_pred)

print("Estimated time for 1M samples:")
print(func(10**6, *popt))

plt.figure(figsize=(10,5))
x_pred = np.linspace(np.min(x) - np.min(x)/2 , np.max(x)*2, 10)
plt.plot(x_pred, func(x_pred, *popt), '--', label="f(x)={:5.3f}*x+{:5.3f}; R^2 = {:5.3f}".format(*(popt), r2) , color = "k", alpha = 0.7)
plt.axvline(x=benchmark_dict[1.0]["n_samples"], color=colors[-1], linestyle="--", label="CalMS21 Task 1")
for i, key in enumerate(benchmark_dict.keys()):
     plt.plot(x[i], y[i], label=f"n = {benchmark_dict[key]['n_samples']} ({key})", marker="o", linestyle="None", markersize=5, color=colors[i])
     plt.errorbar(x[i],y[i], yerr=benchmark_dict[key]["extraction"].std(), ecolor="black")
#plt.plot(benchmark_dict.keys(), benchmark_dict[5.0]["learning"].mean(axis=1), label="5.0")

plt.title("Feature extraction time vs n_samples")
plt.xticks(np.arange(5000, 90000, 10000), ["{:5.0f}k".format(i/1000) for i in np.arange(5000, 90000, 10000)], rotation=45)
plt.xlabel("n_samples")
plt.ylabel("Time (s)")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('../plots/Task1_activespeed_feat.svg', dpi=300, bbox_inches='tight', transparent=True)
plt.show()
# Out:
# Estimated time for 1M samples:
# 1723.8488139304586

# %% [markdown]
# # Runtime without Feature Extraction

# %%
#linear fit

from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

def func(x, a, b):
    """Return values from a general log function."""
    return a * x + b

x = np.array([benchmark_dict[key]["n_samples"] for key in benchmark_dict.keys()])
y = [benchmark_dict[key]["learning"].sum(axis=0).mean() for key in benchmark_dict.keys()]

popt, pcov = curve_fit(func, x, y)

y_pred = func(x, *popt)
r2 = r2_score(y, y_pred)

print("Estimated time for 1M samples:")
print(func(10**6, *popt))

plt.figure(figsize=(10,5))
x_pred = np.linspace(np.min(x) - np.min(x)/2 , np.max(x)*2, 10)
plt.plot(x_pred, func(x_pred, *popt), '--'
         , label="f(x)={:5.3f}*x) + {:5.3f}; R^2 = {:5.3f}".format(*(popt), r2)
         , color = "k")
plt.axvline(x=benchmark_dict[1.0]["n_samples"], color=colors[-1], linestyle="--", label="CalMS21 Task 1")
for i, key in enumerate(benchmark_dict.keys()):
     plt.plot(x[i], y[i], label=f"n = {benchmark_dict[key]['n_samples']} ({key})", marker="o", linestyle="None", markersize=5, color=colors[i])
     plt.errorbar(x[i],y[i], yerr=benchmark_dict[key]["learning"].sum(axis = 0).std(), ecolor="black")
#plt.plot(benchmark_dict.keys(), benchmark_dict[5.0]["learning"].mean(axis=1), label="5.0")

plt.title("Total Time vs n_samples")
plt.xticks(np.arange(5000, 90000, 10000), ["{:5.0f}k".format(i/1000) for i in np.arange(5000, 90000, 10000)], rotation=45)
plt.xlabel("n_samples")
plt.ylabel("Time (s)")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('../plots/Task1_activespeed.svg', dpi=300, bbox_inches='tight', transparent=True)
plt.show()
# Out:
# Estimated time for 1M samples:
# 1470.6810709472109

# %% [markdown]
# # Runtime with Feature Extraction

# %%
from scipy.optimize import curve_fit
from sklearn.metrics import r2_score

def func(x, a,c):
    return a*x+c

x = np.array([benchmark_dict[key]["n_samples"] for key in benchmark_dict.keys() if key != 0.1])
y = [benchmark_dict[key]["total"].mean() for key in benchmark_dict.keys() if key != 0.1]

popt, pcov = curve_fit(func, x, y)

y_pred = func(x, *popt)
r2 = r2_score(y, y_pred)

print("Estimated time for 1M samples:")
print(func(10**6, *popt))
print("Estimated time for 100k samples:")
print(func(10**5, *popt))


plt.figure(figsize=(10,5))
x_pred = np.linspace(np.min(x) - np.min(x)/2 , np.max(x)*2, 10)
plt.plot(x_pred, func(x_pred, *popt), '--', label="f(x)={:5.3f}*x+{:5.3f}; R^2 = {:5.3f}".format(*(popt), r2) , color = "k")
plt.axvline(x=benchmark_dict[1.0]["n_samples"], color=colors[-1], linestyle="--", label="CalMS21 Task 1")
for i, key in enumerate(benchmark_dict.keys()):
     print(key, benchmark_dict[key]["total"].mean(), benchmark_dict[key]["total"].std())
     plt.plot(x[i], y[i], label=f"n = {benchmark_dict[key]['n_samples']} ({key})", marker="o", linestyle="None", markersize=5, color=colors[i])
     plt.errorbar(x[i],y[i], yerr=benchmark_dict[key]["total"].std(), ecolor="black")
#plt.plot(benchmark_dict.keys(), benchmark_dict[5.0]["learning"].mean(axis=1), label="5.0")

plt.title("Total Time vs n_samples")
plt.xticks(np.arange(5000, 90000, 10000), ["{:5.0f}k".format(i/1000) for i in np.arange(5000, 90000, 10000)], rotation=45)
plt.xlabel("n_samples")
plt.ylabel("Time (s)")

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
plt.savefig('../plots/Task1_activespeed_inclfeat.svg', dpi=300, bbox_inches='tight', transparent=True)
plt.show()
# Out:
# Estimated time for 1M samples:
# 3194.529887058802
# Estimated time for 100k samples:
# 625.7366290760644
# 0.3 376.8711265722911 1.3770820927176886
# 0.5 400.1153031984965 5.435128440054198
# 0.7 403.52821437517804 1.0889691151060161
# 0.9 448.09874002138775 8.849596741823305
# 1.0 458.33846894900006 5.807263568812995
